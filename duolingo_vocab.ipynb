# %% [markdown]
# .txt file is a property of some kind person on the internet: https://pastebin.com/BjcwEuuN
#
# (found here https://www.reddit.com/r/German/comments/67lbwn/duolingo_german_vocabulary_list/)

# %%
import pandas as pd
import numpy as np

import re
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

stemmer = SnowballStemmer("german")
stop_words = stopwords.words("german")
stop_words.extend([
        'winden','jonas','adam','eva','hanno','noah','sonja',\
        'mikkel','ines','michael','magnus','bartosz','egon','mads','silja','agnes',\
        'ulrich', 'katharina','hannah','martha','jana','tronte','jasmin','helene',\
        'charlotte','regina','franziska','peter','helge','aleksander','boris','claudia','clausen',\
        'elisabeth','elli','yasin','bernd','benni',\
        'albers','kahnwald','nielsen','doppler','tiedemann','niewald','tannhaus','tauber','woller','kruger','obendorf'])

# %%
duo_data = pd.read_csv('duolingo_german_vocab.txt',header=None, sep="; ",engine='python')
duo_data
# Out:
#                  0              1
# 0         der Mann        the man
# 1         die Frau      the woman
# 2        der Junge        the boy
# 3              ich              I
# 4          ich bin           I am
# ...            ...            ...
# 2050    Südamerika  South America
# 2051  die Pyramide    the pyramid
# 2052       Ägypten          Egypt
# 2053      Russland         Russia
# 2054        Türkei         Turkey
#
# [2055 rows x 2 columns]

# %%
duo_data.rename(columns={0:"ger",1:"eng"},inplace=True)
duo_data
# Out:
#                ger            eng
# 0         der Mann        the man
# 1         die Frau      the woman
# 2        der Junge        the boy
# 3              ich              I
# 4          ich bin           I am
# ...            ...            ...
# 2050    Südamerika  South America
# 2051  die Pyramide    the pyramid
# 2052       Ägypten          Egypt
# 2053      Russland         Russia
# 2054        Türkei         Turkey
#
# [2055 rows x 2 columns]

# %% [markdown]
# Saving only ger column with no "die/der/das/ich/du..." for another purpose.

# %%
articles_pronouns_w_spaces = ["die ","der ","das ","ich ","du ","wir ","sie ","ihr ",\
    "wie "]
ger_clean = []
for word in duo_data.ger:
    for i in articles_pronouns_w_spaces:
        if i in word:
            ger_clean.append(word.replace(i,''))
for word in ger_clean:
    if "er " in word:
        word = word.replace("er ",'')
ger_clean
# Out:
# ['Mann',
#  'Frau',
#  'Junge',
#  'bin',
#  'bist',
#  'Kind',
#  'Mädchen',
#  'Brot',
#  'Wasser',
#  'sind',
#  'seid',
#  'Männer',
#  'Frauen',
#  'Jungen',
#  'Kinder',
#  "geht's",
#  'trinke',
#  'trinkst',
#  'trinken',
#  'Milch',
#  'esse',
#  'isst',
#  'essen',
#  'esst',
#  'Apfel',
#  'liest',
#  'Zeitung',
#  'lese',
#  'lesen',
#  'Buch',
#  'Bücher',
#  'habe',
#  'hast',
#  'habt',
#  'haben',
#  'Essen',
#  'Hunger',
#  'Pizza',
#  'Suppe',
#  'Fisch',
#  'Eis',
#  'Tee',
#  'Durst',
#  'Kaffee',
#  'Bier',
#  'Wein',
#  'Obst',
#  'Orange',
#  'Banane',
#  'Saft',
#  'Apfelsaft',
#  'Orangensaft',
#  'Ei',
#  'Käse',
#  'Fleisch',
#  'Gemüse',
#  'Kartoffel',
#  'Schokolade',
#  'Zucker',
#  'Erdbeere',
#  'Salz',
#  'Nudeln',
#  'Reis',
#  'Öl',
#  'Tier',
#  'Katze',
#  'Hund',
#  'Maus',
#  'Bär',
#  'Haustier',
#  'Kuh',
#  'Pferd',
#  'Schwein',
#  'Vogel',
#  'Ente',
#  'Spinne',
#  'Insekt',
#  'Biene',
#  'Käfer',
#  'Fliege',
#  'Tiere',
#  'Katzen',
#  'Hunde',
#  'Fische',
#  'Tomaten',
#  'Zeitungen',
#  'Menschen',
#  'Mädchen',
#  'Insekt',
#  'Orangen',
#  'Äpfel',
#  'Kartoffeln',
#  'Eier',
#  'Kühe',
#  'Schweine',
#  'Vögel',
#  'Bären',
#  'Enten',
#  'Mäuse',
#  'Kleid',
#  'Rock',
#  'Hut',
#  'Schuh',
#  'Kleidung',
#  'Hose',
#  'Hemd',
#  'Jacke',
#  'Tasche',
#  'Knopf',
#  'Schmuck',
#  'Ring',
#  'Natur',
#  'Erde',
#  'Berg',
#  'Baum',
#  'Wind',
#  'Feuer',
#  'Blume',
#  'Luft',
#  'Meer',
#  'Mond',
#  'Himmel',
#  'Sonne',
#  'Stern',
#  'Gebäude',
#  'Haus',
#  'Markt',
#  'Schule',
#  'Garten',
#  'Ecke',
#  'Bahnhof',
#  'Restaurant',
#  'Bibliothek',
#  'Bank',
#  'Hotel',
#  'Straße',
#  'Land',
#  'Stadt',
#  'Dorf',
#  'Brücke',
#  'Park',
#  'Zimmer',
#  'Fahrzeug',
#  'Flugzeug',
#  'Werkzeug',
#  'Spielzeug',
#  'Wand',
#  'Fenster',
#  'Tür',
#  'Zaun',
#  'Treppe',
#  'Wohnung',
#  'Dach',
#  'Balkon',
#  'Keller',
#  'Schlüssel',
#  'Küche',
#  'Wohnzimmer',
#  'Tisch',
#  'Stuhl',
#  'Schrank',
#  'Sofa',
#  'Möbel',
#  'Schlaf',
#  'Bett',
#  'Teppich',
#  'Lampe',
#  'Licht',
#  'Steckdose',
#  'Person',
#  'Freund',
#  'Name',
#  'Vorname',
#  'Mensch',
#  'Leute',
#  'Herr',
#  'Dame',
#  'Bürger',
#  'Publikum',
#  'Gruppe',
#  'Gast',
#  'Vegetarier',
#  'Gegner',
#  'Mitglied',
#  'Anfänger',
#  'Besucher',
#  'Feind',
#  'Nachbar',
#  'viele',
#  'viel',
#  'Frage',
#  'Antwort',
#  'antworten',
#  'Mutter',
#  'Vater',
#  'Schwester',
#  'Bruder',
#  'Tochter',
#  'Sohn',
#  'Familie',
#  'Eltern',
#  'Geschwister',
#  'Partner',
#  'Beziehung',
#  'Großeltern',
#  'Großvater',
#  'Großmutter',
#  'Enkel',
#  'Enkelin',
#  'Oma',
#  'Opa',
#  'Zahl',
#  'Summe',
#  'Hälfte',
#  'Dutzend',
#  'Telefon',
#  'Frühstück',
#  'frühstücken',
#  'Butter',
#  'Marmelade',
#  'Müsli',
#  'Nuss',
#  'Honig',
#  'Mittagessen',
#  'Rezept',
#  'Tomate',
#  'Pilz',
#  'Hähnchen',
#  'koche',
#  'Zitrone',
#  'Getränk',
#  'Speisekarte',
#  'Vorspeise',
#  'Salat',
#  'Knoblauch',
#  'Zwiebel',
#  'Senf',
#  'Nachtisch',
#  'Abendessen',
#  'Löffel',
#  'Gabel',
#  'Messer',
#  'Geld',
#  'Euro',
#  'Cent',
#  'Preis',
#  'Dollar',
#  'Trinkgeld',
#  'Tante',
#  'Onkel',
#  'Nichte',
#  'Neffe',
#  'Cousin',
#  'Cousine',
#  'Zwilling',
#  'Urenkel',
#  'Partnerschaft',
#  'Hochzeit',
#  'Halbbruder',
#  'Halbschwester',
#  'Körper',
#  'Kopf',
#  'Haar',
#  'Auge',
#  'Ohr',
#  'Nase',
#  'Mund',
#  'Zahn',
#  'Hals',
#  'Arm',
#  'Hand',
#  'Finger',
#  'Schulter',
#  'Rücken',
#  'Brust',
#  'Magen',
#  'Herz',
#  'Bein',
#  'Haut',
#  'Fuß',
#  'Blut',
#  'Gesicht',
#  'Auto',
#  'Zug',
#  'Bus',
#  'Urlaub',
#  'Pass',
#  'Sehenswürdigkeit',
#  'Reise',
#  'Zoll',
#  'Boot',
#  'Stadt',
#  'Tourismus',
#  'Weg',
#  'Flug',
#  'Motorrad',
#  'Abenteuer',
#  'Miete',
#  'Strecke',
#  'Verkehr',
#  'Fahrt',
#  'Bahn',
#  'Ferien',
#  'Besuch',
#  'Tour',
#  'Bus',
#  'Reiseführer',
#  'Fähre',
#  'Verspätung',
#  'Bäckerei',
#  'Laden',
#  'Geschäft',
#  'Kunde',
#  'Supermarkt',
#  'Einkauf',
#  'Kasse',
#  'Tüte',
#  'Gutschein',
#  'Apotheke',
#  'Meter',
#  'Prozent',
#  'Liter',
#  'Milliarde',
#  'Million',
#  'Farbe',
#  'Beruf',
#  'Arzt',
#  'Ärztin',
#  'Bäcker',
#  'Bäckerin',
#  'Koch',
#  'Köchin',
#  'Student',
#  'Lehrer',
#  'Lehrerin',
#  'Studentin',
#  'Schülerin',
#  'Schüler',
#  'Professorin',
#  'Professor',
#  'Arbeitgeber',
#  'Mitarbeiter',
#  'Arbeit',
#  'Bürgermeister',
#  'Senior',
#  'Autor',
#  'Trainer',
#  'Chef',
#  'Chefin',
#  'Architekt',
#  'Verkäufer',
#  'Bedienung',
#  'Fahrer',
#  'Feuerwehr',
#  'Bauer',
#  'Glas',
#  'Sand',
#  'Stein',
#  'Wolle',
#  'Beton',
#  'Pappe',
#  'Papier',
#  'Leder',
#  'Holz',
#  'Baumwolle',
#  'Metall',
#  'Gold',
#  'Silber',
#  'Kupfer',
#  'Stahl',
#  'Mauer',
#  'Größe',
#  'Haushalt',
#  'Heizung',
#  'Reinigung',
#  'Umzug',
#  'Gerät',
#  'Schlaf',
#  'Zahnpasta',
#  'Raum',
#  'Leiter',
#  'Batterie',
#  'Toilette',
#  'Tasse',
#  'Tor',
#  'Schüssel',
#  'Teller',
#  'Kühlschrank',
#  'Karton',
#  'Rucksack',
#  'Flasche',
#  'Rasierer',
#  'Bad',
#  'Seife',
#  'Spiegel',
#  'Handtuch',
#  'Dusche',
#  'Tag',
#  'Woche',
#  'Wochenende',
#  'Zukunft',
#  'Vergangenheit',
#  'Anfang',
#  'Ende',
#  'Ort',
#  'Kneipe',
#  'Platz',
#  'Pension',
#  'Unterkunft',
#  'Bereich',
#  'Flughafen',
#  'Bundesland',
#  'Region',
#  'Bezirk',
#  'Grund',
#  'Grundstück',
#  'Zentrale',
#  'Zentrum',
#  'Halle',
#  'Fläche',
#  'Innenstadt',
#  'Innere',
#  'Umgebung',
#  'Ferien',
#  'Heimat',
#  'Insel',
#  'Hauptstadt',
#  'Patient',
#  'Medikament',
#  'Pflaster',
#  'Rollstuhl',
#  'Praxis',
#  'Gesundheit',
#  'Untersuchung',
#  'Formular',
#  'Krankheit',
#  'Medizin',
#  'Krankenhaus',
#  'Versicherung',
#  'Unfall',
#  'Notfall',
#  'Opfer',
#  'Klinik',
#  'Therapie',
#  'Alkohol',
#  'Diät',
#  'Ernährung',
#  'Monat',
#  'Frühling',
#  'Spargel',
#  'Jahr',
#  'Quartal',
#  'Sommer',
#  'Datum',
#  'Kalender',
#  'Jahreszeit',
#  'Saison',
#  'Schluss',
#  'Alter',
#  'Geburtstag',
#  'Phase',
#  'Jahrhundert',
#  'Gemeinde',
#  'Verein',
#  'Öffentlichkeit',
#  'Verbindung',
#  'Verhältnis',
#  'Nutzer',
#  'Bevölkerung',
#  'Jugend',
#  'Mitgliedschaft',
#  'Einwohner',
#  'Paar',
#  'Liebe',
#  'Traum',
#  'Lust',
#  'Not',
#  'Freude',
#  'Wunsch',
#  'Verständnis',
#  'Spaß',
#  'Ernst',
#  'Humor',
#  'Angst',
#  'Eindruck',
#  'Gedanke',
#  'Ruhe',
#  'Witz',
#  'Ärger',
#  'Schuld',
#  'Glück',
#  'Termin',
#  'Moment',
#  'Morgen',
#  'Nachmittag',
#  'Abend',
#  'Nacht',
#  'Zeitraum',
#  'Augenblick',
#  'Uhr',
#  'Zeit',
#  'Stunde',
#  'Minute',
#  'Sekunde',
#  'Dauer',
#  'Mal',
#  'wenoch',
#  'Wiese',
#  'Strand',
#  'Umwelt',
#  'Bernstein',
#  'Welt',
#  'Tier',
#  'See',
#  'Gras',
#  'Welle',
#  'Rhein',
#  'All',
#  'Wald',
#  'Fluss',
#  'Bach',
#  'Pflanze',
#  'Klima',
#  'Strom',
#  'Landwirtschaft',
#  'Wüste',
#  'Verfasser',
#  'Betreiber',
#  'Entwickler',
#  'Personal',
#  'Empfänger',
#  'Teilnehmer',
#  'Werkstatt',
#  'Schneider',
#  'Hersteller',
#  'Richter',
#  'Spezialität',
#  'Experte',
#  'Richterin',
#  'Richtung',
#  'Norden',
#  'Süden',
#  'Osten',
#  'Westen',
#  'Stärke',
#  'Regen',
#  'Wetter',
#  'Grad',
#  'Schnee',
#  'Sturm',
#  'Regenbogen',
#  'Gewitter',
#  'Wolke',
#  'Donner',
#  'Blitz',
#  'Plan',
#  'Büro',
#  'Produkt',
#  'Schere',
#  'Sache',
#  'Katalog',
#  'Boden',
#  'Zubehör',
#  'Stück',
#  'Paket',
#  'Geschenk',
#  'Kommunikation',
#  'Telefon',
#  'Handy',
#  'Vorwahl',
#  'Gespräch',
#  'Information',
#  'Computer',
#  'Monitor',
#  'Festplatte',
#  'Tastatur',
#  'Kabel',
#  'Nachricht',
#  'Artikel',
#  'Interview',
#  'Zeitschrift',
#  'Dialog',
#  'Fernseher',
#  'Medium',
#  'Sendung',
#  'Rede',
#  'Diskussion',
#  'Internet',
#  'Seite',
#  'Suche',
#  'Foto',
#  'Netz',
#  'Anhang',
#  'Profil',
#  'Taste',
#  'Kommentar',
#  'Passwort',
#  'Programm',
#  'Bild',
#  'Leser',
#  'Universität',
#  'Stift',
#  'Grund',
#  'Übung',
#  'Note',
#  'Bildung',
#  'Test',
#  'Forschung',
#  'Studium',
#  'Klasse',
#  'Kurs',
#  'Seminar',
#  'Ausbildung',
#  'Training',
#  'Institut',
#  'Unterricht',
#  'Akademie',
#  'Erziehung',
#  'Uni',
#  'Weiterbildung',
#  'Prüfung',
#  'Kindergarten',
#  'Fachbereich',
#  'Verzeihung',
#  'Wissenschaft',
#  'Definition',
#  'Erfindung',
#  'Technologie',
#  'Theorie',
#  'Kenntnis',
#  'Physik',
#  'Energie',
#  'Temperatur',
#  'Strahlung',
#  'Motor',
#  'Wissen',
#  'Studie',
#  'Maschine',
#  'Methode',
#  'Wissenschaftler',
#  'Wissenschaftlerin',
#  'Praktikum',
#  'Gas',
#  'Kunststoff',
#  'Analyse',
#  'Nachweis',
#  'Atmosphäre',
#  'Post',
#  'Brief',
#  'Adresse',
#  'Anrede',
#  'Gruß',
#  'Notiz',
#  'Briefkasten',
#  'Brief',
#  'Kontakt',
#  'Einladung',
#  'Begründung',
#  'Thema',
#  'Bestätigung',
#  'Verlag',
#  'Meldung',
#  'Lautsprecher',
#  'Radio',
#  'Sender',
#  'Tasche',
#  'Anmeldung',
#  'Mitteilung',
#  'Organisation',
#  'Unternehmen',
#  'Fabrik',
#  'Büro',
#  'Inhaber',
#  'Bestellung',
#  'Kollege',
#  'Beratung',
#  'Projekt',
#  'Management',
#  'Wettbewerb',
#  'Dokument',
#  'Miete',
#  'Beitrag',
#  'Wert',
#  'Gewinn',
#  'Handel',
#  'Verbraucher',
#  'Kauf',
#  'Käufer',
#  'Job',
#  'Bewerbung',
#  'Anzug',
#  'Karriere',
#  'Bedeutung',
#  'Idee',
#  'Wort',
#  'Beschreibung',
#  'Schrift',
#  'Sprache',
#  'Geschichte',
#  'Zustimmung',
#  'Text',
#  'Bericht',
#  'Titel',
#  'Konzept',
#  'Meinung',
#  'Erklärung',
#  'Zeichen',
#  'Kapitel',
#  'Verzeichnis',
#  'Satz',
#  'Unterhaltung',
#  'Zusammenfassung',
#  'Begriff',
#  'Übersetzung',
#  'Problem',
#  'Ziel',
#  'Form',
#  'Verhalten',
#  'Lösung',
#  'Änderung',
#  'Auswahl',
#  'Druck',
#  'Empfehlung',
#  'Nutzen',
#  'Lage',
#  'Ding',
#  'Engagement',
#  'Hilfe',
#  'Kompetenz',
#  'Entwicklung',
#  'Sicherheit',
#  'Ergebnis',
#  'Versuch',
#  'Qualität',
#  'Zusammenarbeit',
#  'Gelegenheit',
#  'Nähe',
#  'Maß',
#  'Eichhörnchen',
#  'Fuchs',
#  'Gans',
#  'Schaf',
#  'Eule',
#  'Schmetterling',
#  'Zoo',
#  'Pinguin',
#  'Säugetier',
#  'Elefant',
#  'Kamel',
#  'Löwe',
#  'Giraffe',
#  'Wal',
#  'Hamster',
#  'Schildkröte',
#  'Affe',
#  'Zebra',
#  'Wespe',
#  'Delfin',
#  'Huhn',
#  'Horn',
#  'Tiger',
#  'Schlange',
#  'Hai',
#  'Wolf',
#  'Gehirn',
#  'Stirn',
#  'Lippe',
#  'Zunge',
#  'Kinn',
#  'Lunge',
#  'Bauch',
#  'Daumen',
#  'Brust',
#  'Ferse',
#  'Ellbogen',
#  'Knöchel',
#  'Hüfte',
#  'Zeh',
#  'Knie',
#  'Oberschenkel',
#  'Leber',
#  'Knochen',
#  'Muskel',
#  'Darm',
#  'Organ',
#  'Leben',
#  'Gefühl',
#  'Sinn',
#  'Spiritualität',
#  'Seele',
#  'Wunder',
#  'Hoffnung',
#  'Geist',
#  'Schicksal',
#  'Gleichgewicht',
#  'Wahrheit',
#  'Zahlung',
#  'Zinsen',
#  'Münze',
#  'Betrag',
#  'Rechnung',
#  'Finanzierung',
#  'Kredit',
#  'Konto',
#  'Frist',
#  'Planung',
#  'Erfahrung',
#  'Version',
#  'Verbesserung',
#  'Basis',
#  'Unterschied',
#  'Kategorie',
#  'Kraft',
#  'Unterstützung',
#  'Liste',
#  'Menge',
#  'Eigenschaft',
#  'Original',
#  'Länge',
#  'Zugang',
#  'Position',
#  'Vorschlag',
#  'Höhe',
#  'Element',
#  'Spalte',
#  'Rolle',
#  'Einführung',
#  'Verwendung',
#  'Hintergrund',
#  'Anleitung',
#  'Feld',
#  'Referenz',
#  'Stufe',
#  'Gewicht',
#  'Party',
#  'Einzelheit',
#  'Wirkung',
#  'Überblick',
#  'Blick',
#  'Kombination',
#  'Zustand',
#  'Kreis',
#  'Umsetzung',
#  'Firma',
#  'Lieferung',
#  'Versicherung',
#  'Verkauf',
#  'Ware',
#  'Tabelle',
#  'Industrie',
#  'Auftrag',
#  'Chance',
#  'Anzeige',
#  'Garantie',
#  'Angebot',
#  'Antrag',
#  'Lager',
#  'Bewertung',
#  'Bezahlung',
#  'Service',
#  'Werbung',
#  'Marke',
#  'Leistung',
#  'Produktion',
#  'Gründung',
#  'Ausgabe',
#  'Stelle',
#  'Börse',
#  'Branche',
#  'Logistik',
#  'Bedarf',
#  'Dienstleistung',
#  'Schwimmbad',
#  'Fahrrad',
#  'Ball',
#  'Aktivität',
#  'Bundesliga',
#  'Zuschauer',
#  'Sport',
#  'Sieg',
#  'Liga',
#  'Team',
#  'Ski',
#  'Teilnahme',
#  'Bewegung',
#  'Freizeit',
#  'Spiel',
#  'Hobby',
#  'Spieler',
#  'Mannschaft',
#  'Gitarre',
#  'Ausstellung',
#  'Galerie',
#  'Studio',
#  'Musiker',
#  'Kunst',
#  'Instrument',
#  'Theater',
#  'Kultur',
#  'Künstler',
#  'Musik',
#  'Start',
#  'Musikinstrument',
#  'Film',
#  'Modell',
#  'Entwurf',
#  'Fotografie',
#  'Sammlung',
#  'Design',
#  'Kritik',
#  'Literatur',
#  'Lied',
#  'Museum',
#  'Jazz',
#  'Bühne',
#  'Tanz',
#  'Mode',
#  'Stil',
#  'Konzert',
#  'Rahmen',
#  'Kamera',
#  'Kino',
#  'Dokumentation',
#  'Tätigkeit',
#  'Schauspieler',
#  'Religion',
#  'Gott',
#  'Tod',
#  'Glaube',
#  'Priester',
#  'Paradies',
#  'Gebet',
#  'Wiedergeburt',
#  'Tempel',
#  'Moschee',
#  'Mönch',
#  'Kirche',
#  'Synagoge',
#  'Präsident',
#  'Partei',
#  'Frieden',
#  'Politik',
#  'Stimme',
#  'Macht',
#  'Erfolg',
#  'Vertrag',
#  'Interesse',
#  'Politiker',
#  'Politikerin',
#  'Republik',
#  'Volk',
#  'König',
#  'Behörde',
#  'Gesetz',
#  'Verwaltung',
#  'Staat',
#  'Wahl',
#  'Königin',
#  'Regierung',
#  'Ministerium',
#  'Recht',
#  'Krieg',
#  'Kampf',
#  'Genehmigung',
#  'Vorschrift',
#  'Prinz',
#  'Prinzessin',
#  'Rathaus',
#  'Regel',
#  'Einfluss',
#  'Kontrolle',
#  'Schaden',
#  'Prozess',
#  'Bedingung',
#  'Entscheidung',
#  'Verfahren',
#  'Anwendung',
#  'Rubrik',
#  'Vergleich',
#  'Förderung',
#  'Anlage',
#  'System',
#  'Kriterium',
#  'Beispiel',
#  'Verlust',
#  'Inhalt',
#  'Eröffnung',
#  'Abschnitt',
#  'Eintritt',
#  'Durchschnitt',
#  'Reparatur',
#  'Anteil',
#  'Auflage',
#  'Ereignis',
#  'Rest',
#  'Geschwindigkeit',
#  'Versorgung',
#  'Verpflichtung',
#  'Tradition',
#  'Agentur',
#  ...]

# %% [markdown]
# "ich bin" and similar entries need to be removed. We don't wanna see all verb conjugations... For the same reason we're not using https://www.duolingo.com/words as it contains plural forms (btw it also does not contain articles)

# %% [markdown]
# # just an exercise

# %%
def clean_text(text):
    
    RE_WSPACE = re.compile(r"\s+", re.IGNORECASE)
    RE_ASCII = re.compile(r"[^A-Za-zÀ-ž ]", re.IGNORECASE)
    RE_SINGLECHAR = re.compile(r"\b[A-Za-zÀ-ž]\b", re.IGNORECASE)
    
    text = re.sub(RE_ASCII, " ", text)
    text = re.sub(RE_SINGLECHAR, " ", text)
    text = re.sub(RE_WSPACE, " ", text)

    word_tokens = word_tokenize(text)
    words_tokens_lower = [word.lower() for word in word_tokens]

    words_filtered = [
        stemmer.stem(word) for word in words_tokens_lower if word not in stop_words
    ]

    text_clean = " ".join(words_filtered)
    return text_clean

# %%
duo_data["ger_clean"] = duo_data.ger.map(
    lambda x: clean_text(x) if isinstance(x, str) else x
)

# %%
duo_data.head(30)
# Out:
#             ger           eng ger_clean
# 0      der Mann       the man      mann
# 1      die Frau     the woman      frau
# 2     der Junge       the boy      jung
# 3           ich             I
# 4       ich bin          I am
# 5           ein           one
# 6          eine             a
# 7            du           you
# 8       du bist       you are
# 9      das Kind     the child      kind
# 10  das Mädchen      the girl     madch
# 11          und           and
# 12     das Brot     the bread      brot
# 13   das Wasser     the water      wass
# 14           er            he
# 15          sie          they
# 16           es            it
# 17          ist            is
# 18    er trinkt     he drinks    trinkt
# 19          wir            we
# 20          ihr           you
# 21     wir sind        we are
# 22     ihr seid       you are      seid
# 23   die Männer       the men      mann
# 24   die Frauen     the women      frau
# 25   die Jungen      the boys      jung
# 26   die Kinder  the children      kind
# 27        hallo         hello     hallo
# 28      tschüss           bye   tschuss
# 29        danke     thank you      dank

# %%
dark_data = pd.read_csv("texts.csv")

# %%
dark_data["text_clean"] = dark_data.episode_text.map(
    lambda x: clean_text(x) if isinstance(x, str) else x
)

# %%
dark_data[0:3]
# Out:
#                                         episode_text  episode  season  \
# 0   - -    Zieh dich um.  -Martha? - Das kann nic...        2       3
# 1        Ich erinnere mich. Ich erinnere mich an ...        7       1
# 2     Das ist nicht mehr lustig!  Katharina?  Ulr...        6       1
#
#   season00episode00                                         text_clean
# 0            S03E02  zieh lebst recht versproch wiedergutzumach pas...
# 1            S01E07  erinn erinn mach jung gefund mhm passiert iden...
# 2            S01E06  mehr lustig mehr lustig hilf hilf hilf albtrau...

# %%
dark_data.text_clean.str.split(' ')
# Out:
# 0     [zieh, lebst, recht, versproch, wiedergutzumac...
# 1     [erinn, erinn, mach, jung, gefund, mhm, passie...
# 2     [mehr, lustig, mehr, lustig, hilf, hilf, hilf,...
# 3     [wusst, andert, imm, bleibt, spinnrad, dreht, ...
# 4     [wusst, ding, end, wohin, reis, fuhrt, trotzd,...
# 5     [schwarz, loch, gelt, hollenschlund, universum...
# 6     [gott, gib, gelass, unaband, hinzunehm, mut, v...
# 7     [kreis, neu, vermisstenfall, erschuttert, stad...
# 8     [dunkel, angezog, mott, licht, dunkel, gebor, ...
# 9     [vertrau, darauf, zeit, linear, verlauft, ewig...
# 10    [warum, sterb, tod, konnt, entkomm, wusst, wan...
# 11    [realitat, gibt, davon, einzig, existi, mehr, ...
# 12    [opf, mannlich, zehn, zeitpunkt, tod, etwa, st...
# 13    [mama, wer, elt, wer, weisst, tun, weh, mach, ...
# 14    [versprech, mach, gut, lieb, hast, versproch, ...
# 15    [anfang, end, end, anfang, miteinand, verbund,...
# 16    [anfang, end, seltsam, vorstell, beid, gleich,...
# 17    [geseh, aufwach, mann, ganz, kreislauf, leb, z...
# 18    [konnt, gottesteilch, resultier, mass, stabili...
# 19    [angefang, ding, begonn, vergang, zukunft, wer...
# 20    [mensch, eigenart, geschopf, all, handeln, mot...
# 21    [eigenart, grosst, abneig, ausgerechnet, mensc...
# 22    [hey, passiert, woh, hast, will, haus, viellei...
# 23    [reis, anfang, end, besteht, imm, fort, reis, ...
# 24    [dank, schnell, arbeit, fand, beid, leich, ja,...
# 25    [seit, jeh, ratselt, mensch, herkunft, entsteh...
# Name: text_clean, dtype: object

# %%
all_words =[]
for line in dark_data.text_clean.str.split(' '):
    for word in line:
        all_words.append(word)
all_words = set(all_words)

# %%
found = []
for word in all_words:
    if word in list(duo_data.ger_clean.drop_duplicates()):
        found.append(word)

# %%
100*len(found)/len(all_words)
# Out:
# 25.4933765882671
